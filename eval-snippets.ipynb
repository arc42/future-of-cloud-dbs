# %% [markdown]
# ## Plain SQLite

# %% [markdown]
# ## Create a simple SQLite database first
#
# Please note - this is to show sqlite connection only, for real code you might add a "if exists".
#
# Code further below contains updates versions of table creation - read on...

# %%
import sqlite3

# Create connection and cursor
conn = sqlite3.connect('cities.db')
cursor = conn.cursor()

# Create table
cursor.execute('''
   CREATE TABLE cities (
       city TEXT,
       country TEXT
   )
''')

# Insert records
cursor.execute(
    'INSERT INTO cities VALUES (?, ?)', 
    ('Paris', 'France'))
cursor.execute(
    'INSERT INTO cities VALUES (?, ?)', 
    ('Tokyo', 'Japan'))
conn.commit()

# Close connection
conn.close()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[132], line 8
#       5 cursor = conn.cursor()
#       7 # Create table
# ----> 8 cursor.execute('''
#       9    CREATE TABLE cities (
#      10        city TEXT,
#      11        country TEXT
#      12    )
#      13 ''')
#      15 # Insert records
#      16 cursor.execute('INSERT INTO cities VALUES (?, ?)', ('Paris', 'France'))
#
# OperationalError: table cities already exists

# %% [markdown]
# ## Add huge amounts of (fictious) data
#
# Prior, make sure to install `faker`:
#
# `pip install faker`
#
# This is also meant as a small showcase only - other versions (see below) create data
# for multiple databases...

# %%
from faker import Faker
import pandas as pd
import sqlite3 as sqlite


fake = Faker()

# Generate fake city-country pairs with random number of inhabitants
num_records = 200000  # adjust as needed
cities_data = [(fake.city(), fake.country(), fake.random_number()) for _ in range(num_records)]

# Create sqlite connection
conn = sqlite.connect('manymanycities.db')

# Create DataFrame
df = pd.DataFrame(cities_data, columns=['city', 'country', 'inhabitants'])

# Insert data directly from DataFrame to SQLite
df.to_sql('cities', conn, if_exists='append', index=False)

# 
# Display sample
display(df.sort_values(by=['inhabitants']).head(10))
# Out:
#                         city                               country  \
# 129083            Morganfurt  United States Minor Outlying Islands
# 32478            Salinasport                              Ethiopia
# 123135          South Austin                        American Samoa
# 180229              Kathyton                               Namibia
# 180246      South Jacobshire                              Anguilla
# 78285            Port Lauren                           El Salvador
# 123065            Hectorfort                               Vietnam
# 123048           Deannaburgh                                Belize
# 51844             Moraleston                                Cyprus
# 78334   South Christinamouth                          Saudi Arabia
#
#         inhabitants
# 129083            0
# 32478             0
# 123135            0
# 180229            0
# 180246            0
# 78285             0
# 123065            0
# 123048            0
# 51844             0
# 78334             0

# %% [markdown]
# ## Add fictional data to all databases (SQLite, PostgreSQL (local), PostgreSQL (supabase), Turso (remote) and Turso (embedded replica)
#
# Prerequisite: `pip install psycopg2-binary sqlalchemy`
#
# Prior to running this script, we have to start the postgres:latest docker container:
#
# ```bash
# # Create the local directory if it doesn't exist
# mkdir -p $PWD/postgresdata
#
# # Run PostgreSQL with bind mount to local directory
# docker run --name cities-postgres \
#    -e POSTGRES_PASSWORD=postgres \
#    -e POSTGRES_DB=cities_db \
#    -p 5432:5432 \
#    -v $PWD/postgresdata:/var/lib/postgresql/data \
#    -d postgres:latest
# ```
#
# Later you re-start this container using `docker start cities-postgres``
#
#
# ### Supabase
#
# We need a database user and password (currently stored in the `.env` file.)
#
# For that to work, we needed:
#
# ```
# from dotenv import load_dotenv
# load_dotenv()
# ```
#
# ### Turso, Remote Only
#
# * Have the turso CLI installed, be authenticated: `turso auth signup`
#
# * Create a remote Turso DB on the command line: `turso db create --group <GROUP> cities
#
# My `default` group consists of AMS, LAX and SYD (Amsterdam, Los-Angeles and Sydney)
#
# > #### The code below showed irregular behavior sometimes
# >
# >
#
#
# >Created database cities at group default in 3.461s.
# >
# >Start an interactive SQL shell with:
# >
# >    `turso db shell cities`
# >
# >To see information about the database, including a connection URL, run:
# >
# >   `turso db show cities`
# >
# >To get an authentication token for the database, run:
# >
# >   `turso db tokens create cities`
#
# ### Turso with Embedded Replica
#
# add name of local (sqlite/libsql) database file as first parameter when creating connection

# %%
from faker import Faker
import pandas as pd
import sqlite3 as sqlite
import libsql_experimental as libsql
import psycopg2
from datetime import datetime
from sqlalchemy import create_engine, text
import os
import logging

from dotenv import load_dotenv


load_dotenv()
logging.getLogger('libsql').setLevel(logging.WARNING)


def write_to_sqlite(df: pd.DataFrame, db_path: str) -> float:
   if os.path.exists(db_path):
       os.remove(db_path)
       print(f"Removed existing SQLite database: {db_path}")
   
   start_time = datetime.now()
   conn = sqlite.connect(db_path)
   df.to_sql('cities', conn, if_exists='append', index=False)
   
   print("Creating SQLite index on country column...")
   cursor = conn.cursor()
   cursor.execute('CREATE INDEX idx_cities_country ON cities(country)')
   conn.commit()
   conn.close()
   
   duration = (datetime.now() - start_time).total_seconds()
   return duration


def write_to_postgres(df: pd.DataFrame, db_params: dict, db_name: str = "docker") -> float:
   """Write to either Docker Postgres or Supabase Postgres based on db_name."""
   start_time = datetime.now()
   
   print(f"Connecting to Postgres ({db_name})...")
   engine = create_engine(
       f"postgresql://{db_params['user']}:{db_params['password']}@"
       f"{db_params['host']}:{db_params['port']}/{db_params['database']}"
   )
   
   with engine.connect() as conn:
       print(f"Dropping existing {db_name} PostgreSQL table 'cities' if exists...")
       conn.execute(text("DROP TABLE IF EXISTS cities"))
       
       print(f"Creating fresh cities table in {db_name}...")
       conn.execute(text("""
           CREATE TABLE cities (
               city VARCHAR(100),
               country VARCHAR(100),
               inhabitants INTEGER
           )
       """))
       
       print(f"Creating index on country column in {db_name}...")
       conn.execute(text("CREATE INDEX idx_cities_country ON cities(country)"))
       conn.commit()
   
   df.to_sql('cities', engine, if_exists='append', index=False, method='multi')
   
   duration = (datetime.now() - start_time).total_seconds()
   return duration

# =============================================================================

def write_to_turso(df: pd.DataFrame, config: dict, db_type: str) -> float:
    """Write to either remote or embedded Turso database."""
    start_time = datetime.now()
    
    print(f"\nConnecting to Turso {db_type}...")
    if db_type == 'remote':
        conn = libsql.connect(config['url'], auth_token=config['auth_token'])
    else:  # embedded
        conn = libsql.connect(
            config['url'],
            sync_url=config['sync_url'],
            auth_token=config['auth_token']
        )
        conn.sync()
    
    cursor = conn.cursor()
    
    print(f"Dropping existing Turso {db_type} table 'cities' if exists...")
    cursor.execute("DROP TABLE IF EXISTS cities")
    conn.commit()
    
    print(f"Creating fresh cities table in Turso {db_type}...")
    cursor.execute("""
        CREATE TABLE cities (
            city TEXT,
            country TEXT,
            inhabitants INTEGER
        )
    """)
    
    print(f"Creating index on country column in Turso {db_type}...")
    cursor.execute("CREATE INDEX idx_cities_country ON cities(country)")
    
    # Bulk insert all records
    values = [tuple(x) for x in df.values]
    cursor.executemany(
        "INSERT INTO cities (city, country, inhabitants) VALUES (?, ?, ?)",
        values
    )
    
    conn.commit()
    
    if db_type == 'embedded':
        conn.sync()
    
    duration = (datetime.now() - start_time).total_seconds()
    return duration

def main():
   # Configuration
   num_records = 1000
   sqlite_path = 'manymanycities.db'
   
   docker_postgres_params = {
       'host': 'localhost',
       'port': 5432,
       'database': 'cities_db',
       'user': 'postgres',
       'password': 'postgres'
   }
   
   supabase_postgres_params = {
       'host': 'aws-0-eu-central-1.pooler.supabase.com',
       'port': 6543,
       'database': 'postgres',
       'user': 'postgres.wotxoncedjsyxktvohuz',
       'password': os.getenv('SUPABASE_PASSWORD')  # Replace with actual password
   }
   
   turso_remote_params = {
        'url': os.getenv('TURSO_REMOTE_DATABASE_URL'),
        'auth_token': os.getenv('TURSO_REMOTE_AUTH_TOKEN')
    }
   
   turso_embedded_params = {
        'url': 'turso-embedded-cities.db',  # local database path
        'sync_url': os.getenv('TURSO_EMBEDDED_SYNC_URL'),       # remote sync URL
        'auth_token': os.getenv('TURSO_EMBEDDED_AUTH_TOKEN')
}
    

       
   # Generate data
   print(f"Generating {num_records} fake records...")
   fake = Faker()
   cities_data = [(fake.city(), fake.country(), fake.random_number()) 
                  for _ in range(num_records)]
   df = pd.DataFrame(cities_data, columns=['city', 'country', 'inhabitants'])
   
   # Write to all three databases
   print("\nWriting to SQLite...")
   sqlite_duration = write_to_sqlite(df, sqlite_path)
   print(f"SQLite write duration: {sqlite_duration:.2f} seconds")
   
   print("\nWriting to Docker PostgreSQL...")
   docker_pg_duration = write_to_postgres(df, docker_postgres_params, "docker")
   print(f"Docker PostgreSQL write duration: {docker_pg_duration:.2f} seconds")
   
   print("\nWriting to Supabase PostgreSQL...")
   supabase_pg_duration = write_to_postgres(df, supabase_postgres_params, "supabase")
   print(f"Supabase PostgreSQL write duration: {supabase_pg_duration:.2f} seconds")
   
   print("\nWriting to Turso remote...")
   turso_remote_duration = write_to_turso(df, turso_remote_params, "remote")
   print(f"Turso remote write duration: {turso_remote_duration:.2f} seconds")

   print("\nWriting to Turso embedded...")
   turso_embedded_duration = write_to_turso(df, turso_embedded_params, "embedded")
   print(f"Turso embedded write duration: {turso_embedded_duration:.2f} seconds")
   
   # Print summary
   print("\nSummary of write performance:")
   print(f"SQLite: {sqlite_duration:.2f} seconds")
   print(f"Docker PostgreSQL: {docker_pg_duration:.2f} seconds")
   print(f"Supabase PostgreSQL: {supabase_pg_duration:.2f} seconds")
   print(f"Turso remote: {turso_remote_duration:.2f} seconds")
   print(f"Turso embedded: {turso_embedded_duration:.2f} seconds")
   print(f"\nRecords written to each database: {num_records}")

if __name__ == "__main__":
   main()
# Out:
# Generating 1000 fake records...
#
# Writing to SQLite...
# Removed existing SQLite database: manymanycities.db
# Creating SQLite index on country column...
# SQLite write duration: 0.00 seconds
#
# Writing to Docker PostgreSQL...
# Connecting to Postgres (docker)...
# Dropping existing docker PostgreSQL table 'cities' if exists...
# Creating fresh cities table in docker...
# Creating index on country column in docker...
# Docker PostgreSQL write duration: 0.08 seconds
#
# Writing to Supabase PostgreSQL...
# Connecting to Postgres (supabase)...
# Dropping existing supabase PostgreSQL table 'cities' if exists...
# Creating fresh cities table in supabase...
# Creating index on country column in supabase...
# Supabase PostgreSQL write duration: 0.43 seconds
#
# Writing to Turso remote...
#
# Connecting to Turso remote...
# Dropping existing Turso remote table 'cities' if exists...
# Creating fresh cities table in Turso remote...
# Creating index on country column in Turso remote...

# %% [markdown]
# ## Read from existing SQLite database
#
# That is what happens within a regular application...

# %%
import sqlite3
from datetime import datetime

# Create connection and cursor
conn = sqlite3.connect('manymanycities.db')
cursor = conn.cursor()

# Start timer
start_time = datetime.now()

# Query and print one record
cursor.execute('SELECT * FROM cities WHERE country = ?', ('France',))

# End timer and calculate duration
end_time = datetime.now()
duration = end_time - start_time


results = cursor.fetchall()
print(f'Execution time: {duration.total_seconds()} seconds')
print(f'Microseconds: {duration.microseconds}')

print(f'Size of the cursor: {len(results)}')
print(results)

# Close connection
conn.close()
# Out:
# Execution time: 0.001142 seconds
# Microseconds: 1142
# Size of the cursor: 805
# [('West Brian', 'France', 24667252), ('Bradleyhaven', 'France', 7568), ('Waynefort', 'France', 7971835), ('Lake Jasmine', 'France', 31), ('Port Rhonda', 'France', 0), ('Jeffreychester', 'France', 4605), ('Manueltown', 'France', 86646), ('Smithtown', 'France', 54727555), ('South Samanthaton', 'France', 2), ('North Heather', 'France', 795557), ('Reedland', 'France', 437), ('Joannaport', 'France', 5), ('West Justinton', 'France', 2), ('Maychester', 'France', 412144583), ('Davidville', 'France', 75576480), ('Crystalshire', 'France', 21893426), ('Hicksfort', 'France', 0), ('New Brooke', 'France', 62), ('East Noahton', 'France', 4879), ('Yorkville', 'France', 714399), ('North Dawnmouth', 'France', 8081392), ('Colemanside', 'France', 98550275), ('West Shawn', 'France', 854), ('Laurenbury', 'France', 90), ('New Jacquelinebury', 'France', 675300336), ('Port Michaelmouth', 'France', 2341), ('New Paulview', 'France', 0), ('Troyland', 'France', 37), ('Simonbury', 'France', 43629), ('Port Jerryborough', 'France', 1819), ('Waretown', 'France', 152), ('Briannaborough', 'France', 11326), ('Carolineton', 'France', 7292595), ('Pattonton', 'France', 9), ('Diazmouth', 'France', 31), ('South Kristenland', 'France', 66), ('Cookbury', 'France', 95171263), ('Brianburgh', 'France', 469351), ('Richardsonstad', 'France', 1080), ('North Richard', 'France', 8313959), ('Willishaven', 'France', 388344), ('East Suzanneton', 'France', 538681826), ('Whiteport', 'France', 1691), ('Daltontown', 'France', 66671740), ('South Rebeccamouth', 'France', 7885), ('Bethbury', 'France', 13324720), ('New Janice', 'France', 37260), ('North Jennifer', 'France', 7832498), ('North Stephenburgh', 'France', 197215568), ('Potterside', 'France', 332372575), ('South Haleyborough', 'France', 4), ('Millsmouth', 'France', 312), ('West Marissatown', 'France', 8698846), ('Marytown', 'France', 123), ('Santosbury', 'France', 8), ('Lake Cheryl', 'France', 7), ('North Sara', 'France', 1323255), ('New Diane', 'France', 5912522), ('Christinefurt', 'France', 859), ('Michaelview', 'France', 563892413), ('North Nataliehaven', 'France', 63), ('Norrishaven', 'France', 25651566), ('Nataliebury', 'France', 71592), ('Sheilaport', 'France', 98859280), ('Ambertown', 'France', 5229724), ('Margaretmouth', 'France', 1), ('Lake Tanya', 'France', 394919889), ('Kelseyland', 'France', 7520), ('Richardsport', 'France', 315), ('Lake Tracey', 'France', 65), ('Lopezside', 'France', 66188), ('Sanchezland', 'France', 1), ('Jessicabury', 'France', 963026), ('New Peterville', 'France', 171999422), ('Jaredfort', 'France', 21), ('North Devin', 'France', 371525), ('East James', 'France', 9), ('Lopezton', 'France', 84343707), ('East Coreyville', 'France', 719268), ('Reeseville', 'France', 819), ('Lake Scottborough', 'France', 507682), ('Sharonton', 'France', 660157), ('Shawborough', 'France', 25938), ('Garcialand', 'France', 639716212), ('West Marcushaven', 'France', 5816009), ('Shannonburgh', 'France', 58138), ('Malikmouth', 'France', 92), ('Kimberlyburgh', 'France', 48140448), ('Kennedyshire', 'France', 2390), ('South James', 'France', 99850622), ('Michelleport', 'France', 95606), ('Johnstonport', 'France', 314759), ('Johnfort', 'France', 47806), ('West Anthony', 'France', 63287696), ('Kellyfort', 'France', 905053), ('West Melissafort', 'France', 1761406), ('Thomasshire', 'France', 43920), ('Donaldsonmouth', 'France', 30888), ('Tonyberg', 'France', 661525), ('West Phillipfurt', 'France', 1199970), ('Lake Christopherborough', 'France', 138), ('North Javierton', 'France', 565110712), ('Rodriguezshire', 'France', 44089), ('South Linda', 'France', 68187265), ('East Lori', 'France', 7), ('New Anthony', 'France', 46), ('Michaelton', 'France', 41501), ('Brandonmouth', 'France', 65296414), ('Lake Jacquelineburgh', 'France', 514794), ('Carlosview', 'France', 718553775), ('South Christopher', 'France', 6909822), ('Freemanchester', 'France', 8996), ('Jasonburgh', 'France', 621278), ('East Tara', 'France', 15945), ('Nguyenhaven',  ...

# %% [markdown]
# ## Use `libSQL` to read from SQLite database
#
# find more details here: https://docs.turso.tech/sdk/python/quickstart#local-only
#
# `pip install libsql-experimental`

# %%
import libsql_experimental as libsql
from datetime import datetime

conn = libsql.connect("manymanycities.db")
cursor = conn.cursor()

# Start timer
start_time = datetime.now()

# Query and print one record
cursor.execute('SELECT * FROM cities WHERE country = ?', ('France',))

# End timer and calculate duration
end_time = datetime.now()
duration = end_time - start_time

results = cursor.fetchall()
print(results)

print(f'Execution time: {duration.total_seconds()} seconds')
print(f'Microseconds: {duration.microseconds}')

# Close connection
# conn.close()
# Out:
# [('Port Sophia', 'France', 87652), ('Hayleyborough', 'France', 2), ('Loriport', 'France', 943677039), ('Samanthaland', 'France', 5962495), ('Mullinsland', 'France', 69708843), ('New Judy', 'France', 152196), ('Noahmouth', 'France', 10136), ('South Timothy', 'France', 44), ('Susanburgh', 'France', 11621238), ('Lake Michelle', 'France', 220180), ('Lamport', 'France', 4945173), ('New Frederickville', 'France', 654045), ('Hallland', 'France', 28), ('East Michael', 'France', 2), ('East Christopherstad', 'France', 3), ('Robertmouth', 'France', 1039284), ('Dudleyland', 'France', 307), ('Carlosfurt', 'France', 987827903), ('West Eddieberg', 'France', 6), ('Charlestown', 'France', 622), ('Port Thomas', 'France', 9630790), ('New Angelabury', 'France', 245), ('Alexanderfurt', 'France', 40102), ('Lake Ericfort', 'France', 1193143), ('South Traceyhaven', 'France', 0), ('Amandaland', 'France', 60669), ('East Natalie', 'France', 9956), ('West Meganmouth', 'France', 41013), ('Port James', 'France', 28), ('Port David', 'France', 703), ('South Robert', 'France', 7), ('Lindsayhaven', 'France', 1076530), ('Parkerview', 'France', 50575238), ('Lake Richardview', 'France', 858875130), ('North Julia', 'France', 89986), ('Port Christine', 'France', 6412709), ('East Trevor', 'France', 1029), ('New Jessica', 'France', 66), ('Sandershaven', 'France', 2), ('North Jennifer', 'France', 7565), ('North Heathertown', 'France', 38528778), ('Amberhaven', 'France', 7), ('Paulville', 'France', 8), ('North Robert', 'France', 80), ('Abigailfurt', 'France', 8), ('New Makaylastad', 'France', 505), ('Port Phillipfurt', 'France', 6826), ('Lake Lindaland', 'France', 560836203), ('South William', 'France', 609121413), ('North Charles', 'France', 60035), ('Markton', 'France', 849559032), ('Penabury', 'France', 296972), ('West Jeffery', 'France', 49249), ('North Tanyatown', 'France', 5190635), ('Christineburgh', 'France', 52), ('Jasonchester', 'France', 93210), ('New Danielmouth', 'France', 196425078), ('Monroetown', 'France', 28), ('Alecstad', 'France', 46527), ('Lake Melissa', 'France', 223696), ('Millershire', 'France', 114843), ('Port John', 'France', 31786), ('Brandonview', 'France', 2), ('North Benjaminburgh', 'France', 2307954), ('New Melissa', 'France', 706502), ('Donaldberg', 'France', 9), ('New Antonio', 'France', 31), ('Vargashaven', 'France', 759941298), ('Lake Danielberg', 'France', 27), ('Blairstad', 'France', 9), ('Thomastown', 'France', 3739469), ('Timothymouth', 'France', 41602), ('East Alisha', 'France', 9), ('Lake Laura', 'France', 224105), ('Leeton', 'France', 543), ('Lake Jasonberg', 'France', 400588736), ('Nataliemouth', 'France', 193344570), ('Nicoleburgh', 'France', 4), ('Emilyberg', 'France', 5073), ('Hughesside', 'France', 43791), ('Kathleenborough', 'France', 3639491), ('Lake Cassandramouth', 'France', 173), ('West Franklinton', 'France', 137310), ('Jenniferstad', 'France', 25132868), ('North Richardstad', 'France', 818051383), ('North Michelleburgh', 'France', 2722), ('Sarahfort', 'France', 30), ('West Johnstad', 'France', 4726), ('West Lauriestad', 'France', 2), ('Lindaport', 'France', 2), ('Martinton', 'France', 7), ('Port Pamelaville', 'France', 822896236), ('East Jackie', 'France', 946365), ('South Mackenzieshire', 'France', 6362), ('Mejiashire', 'France', 27), ('New Kennethfurt', 'France', 1952), ('West Andrew', 'France', 35179), ('West Danielport', 'France', 6282), ('Parkside', 'France', 160612672), ('Daychester', 'France', 88), ('South Austinview', 'France', 33628), ('Christinabury', 'France', 3142629), ('Schmidtside', 'France', 8854), ('Patriciabury', 'France', 839947), ('Lake Sue', 'France', 190884), ('East Stephanie', 'France', 949247293), ('North Aaronton', 'France', 59109095), ('New Scottfort', 'France', 87), ('Port Veronicaport', 'France', 7867246), ('Johnbury', 'France', 277809), ('Lake Bethany', 'France', 2), ('East Randy', 'France', 55), ('Kentton', 'France', 96), ('Laurenburgh', 'France', 8921), ('Mayofurt', 'France', 93699779),  ...
# Execution time: 0.000221 seconds
# Microseconds: 221

# %% [markdown]
# ## Read from existing PostgreSQL DB

# %%
import psycopg2
from datetime import datetime

# Create connection and cursor
conn = psycopg2.connect(
   dbname="cities_db",
   user="postgres",
   password="postgres",
   host="localhost",
   port="5432"
)
cursor = conn.cursor()

# Start timer
start_time = datetime.now()

# Query and print one record
# Note: PostgreSQL uses %s instead of ? for parameters
cursor.execute('SELECT * FROM cities WHERE country = %s', ('France',))

# End timer and calculate duration
end_time = datetime.now()
duration = end_time - start_time

results = cursor.fetchall()
print(f'Execution time: {duration.total_seconds()} seconds')
print(f'Microseconds: {duration.microseconds}')

print(f'Size of the cursor: {len(results)}')
print(results)

# Close connection
cursor.close()
conn.close()
# Out:
# Execution time: 0.003954 seconds
# Microseconds: 3954
# Size of the cursor: 805
# [('West Brian', 'France', 24667252), ('Bradleyhaven', 'France', 7568), ('Waynefort', 'France', 7971835), ('Lake Jasmine', 'France', 31), ('Port Rhonda', 'France', 0), ('Jeffreychester', 'France', 4605), ('Manueltown', 'France', 86646), ('Smithtown', 'France', 54727555), ('South Samanthaton', 'France', 2), ('North Heather', 'France', 795557), ('Reedland', 'France', 437), ('Joannaport', 'France', 5), ('West Justinton', 'France', 2), ('Maychester', 'France', 412144583), ('Davidville', 'France', 75576480), ('Crystalshire', 'France', 21893426), ('Hicksfort', 'France', 0), ('New Brooke', 'France', 62), ('East Noahton', 'France', 4879), ('Yorkville', 'France', 714399), ('North Dawnmouth', 'France', 8081392), ('Colemanside', 'France', 98550275), ('West Shawn', 'France', 854), ('Laurenbury', 'France', 90), ('New Jacquelinebury', 'France', 675300336), ('Port Michaelmouth', 'France', 2341), ('New Paulview', 'France', 0), ('Troyland', 'France', 37), ('Simonbury', 'France', 43629), ('Port Jerryborough', 'France', 1819), ('Waretown', 'France', 152), ('Briannaborough', 'France', 11326), ('Carolineton', 'France', 7292595), ('Pattonton', 'France', 9), ('Diazmouth', 'France', 31), ('South Kristenland', 'France', 66), ('Cookbury', 'France', 95171263), ('Brianburgh', 'France', 469351), ('Richardsonstad', 'France', 1080), ('North Richard', 'France', 8313959), ('Willishaven', 'France', 388344), ('East Suzanneton', 'France', 538681826), ('Whiteport', 'France', 1691), ('Daltontown', 'France', 66671740), ('South Rebeccamouth', 'France', 7885), ('Bethbury', 'France', 13324720), ('New Janice', 'France', 37260), ('North Jennifer', 'France', 7832498), ('North Stephenburgh', 'France', 197215568), ('Potterside', 'France', 332372575), ('South Haleyborough', 'France', 4), ('Millsmouth', 'France', 312), ('West Marissatown', 'France', 8698846), ('Marytown', 'France', 123), ('Santosbury', 'France', 8), ('Lake Cheryl', 'France', 7), ('North Sara', 'France', 1323255), ('New Diane', 'France', 5912522), ('Christinefurt', 'France', 859), ('Michaelview', 'France', 563892413), ('North Nataliehaven', 'France', 63), ('Norrishaven', 'France', 25651566), ('Nataliebury', 'France', 71592), ('Sheilaport', 'France', 98859280), ('Ambertown', 'France', 5229724), ('Margaretmouth', 'France', 1), ('Lake Tanya', 'France', 394919889), ('Kelseyland', 'France', 7520), ('Richardsport', 'France', 315), ('Lake Tracey', 'France', 65), ('Lopezside', 'France', 66188), ('Sanchezland', 'France', 1), ('Jessicabury', 'France', 963026), ('New Peterville', 'France', 171999422), ('Jaredfort', 'France', 21), ('North Devin', 'France', 371525), ('East James', 'France', 9), ('Lopezton', 'France', 84343707), ('East Coreyville', 'France', 719268), ('Reeseville', 'France', 819), ('Lake Scottborough', 'France', 507682), ('Sharonton', 'France', 660157), ('Shawborough', 'France', 25938), ('Garcialand', 'France', 639716212), ('West Marcushaven', 'France', 5816009), ('Shannonburgh', 'France', 58138), ('Malikmouth', 'France', 92), ('Kimberlyburgh', 'France', 48140448), ('Kennedyshire', 'France', 2390), ('South James', 'France', 99850622), ('Michelleport', 'France', 95606), ('Johnstonport', 'France', 314759), ('Johnfort', 'France', 47806), ('West Anthony', 'France', 63287696), ('Kellyfort', 'France', 905053), ('West Melissafort', 'France', 1761406), ('Thomasshire', 'France', 43920), ('Donaldsonmouth', 'France', 30888), ('Tonyberg', 'France', 661525), ('West Phillipfurt', 'France', 1199970), ('Lake Christopherborough', 'France', 138), ('North Javierton', 'France', 565110712), ('Rodriguezshire', 'France', 44089), ('South Linda', 'France', 68187265), ('East Lori', 'France', 7), ('New Anthony', 'France', 46), ('Michaelton', 'France', 41501), ('Brandonmouth', 'France', 65296414), ('Lake Jacquelineburgh', 'France', 514794), ('Carlosview', 'France', 718553775), ('South Christopher', 'France', 6909822), ('Freemanchester', 'France', 8996), ('Jasonburgh', 'France', 621278), ('East Tara', 'France', 15945), ('Nguyenhaven',  ...

# %% [markdown]
# ## Comparing the  Databases SQLite, libSQL and PostgreSQL (on local docker and remote supabase) and Turso (remote and embedded-replica)
#
# Let us modularize and improve:
#
# * Separate DB initialization and query execution into distinct functions
# * Provide a benchmark function that runs multiple iterations
# * Calculate key statistics (mean, median, 95th percentile, etc.)
# * Use tabulate to create a nice comparison table
# * Convert times to milliseconds for better readability
#
# We need to install tabulate and other dependencies
#
# `pip install tabulate, python-dotenv`
#
# #### handling secrets
#
# Secrets (API-keys and/or passwords) are read from the `.env` file via `os.getenv()`

# %%
import libsql_experimental as libsql
import sqlite3
import psycopg2
from datetime import datetime
import statistics
from sqlalchemy import null
from tabulate import tabulate
from typing import List, Tuple, Any
import os

from dotenv import load_dotenv
load_dotenv()

# Database configurations
LIBSQL_CONFIG = {
    'db_path': 'manymanycities.db'
}

SQLITE_CONFIG = {
    'db_path': 'manymanycities.db'
}

POSTGRES_CONFIG = {
    'dbname': "cities_db",
    'user': "postgres",
    'password': "postgres",
    'host': "localhost",
    'port': "5432"
}

SUPABASE_CONFIG = {
    'host': 'aws-0-eu-central-1.pooler.supabase.com',
    'port': 6543,
    'database': 'postgres',
    'user': 'postgres.wotxoncedjsyxktvohuz',
    'password': os.getenv('SUPABASE_PASSWORD')
}

  
TURSO_REMOTE_CONFIG = {
    'url': os.getenv('TURSO_REMOTE_DATABASE_URL'),
    'auth_token': os.getenv('TURSO_REMOTE_AUTH_TOKEN')
}

TURSO_EMBEDDED_CONFIG = {
    'url': 'turso-embedded-cities.db',  # local database path
    'sync_url': os.getenv('TURSO_EMBEDDED_SYNC_URL'),       # remote sync URL
    'auth_token': os.getenv('TURSO_EMBEDDED_AUTH_TOKEN')
}



# init_db returns a connection
def init_db(config: dict, db_type: str = 'libsql'):
    if db_type == 'libsql':
        return libsql.connect(config['db_path'])
    elif db_type == 'postgres':
        return psycopg2.connect(**config)
    elif db_type == 'supabase':
        return psycopg2.connect(**config)
    elif db_type == 'turso-remote':
        return libsql.connect(config['url'], auth_token=config['auth_token'])
    elif db_type == 'turso-embedded':
        conn = libsql.connect( config['url'],
            sync_url=config['sync_url'],
            auth_token=config['auth_token']
        )
        conn.sync()
        return conn
    else:  # sqlite
        return sqlite3.connect(config['db_path'])

def execute_query(conn, query: str, params: Tuple = None) -> Tuple[List[Any], float]:
    cursor = conn.cursor()
    start_time = datetime.now()
    # PostgreSQL uses %s instead of ? for parameters
    if isinstance(conn, psycopg2.extensions.connection):
        query = query.replace('?', '%s')
    cursor.execute(query, params or ())
    results = cursor.fetchall()
    duration = (datetime.now() - start_time).microseconds
    return results, duration

def get_all_countries(conn, dbname) -> List[str]:
    cursor = conn.cursor()
    cursor.execute('SELECT DISTINCT country FROM cities ORDER BY country')
    countries = [row[0] for row in cursor.fetchall()]
    print(f"Found {len(countries)} unique countries in {dbname} : {', '.join(countries)}")
    return countries

def run_benchmark(config: dict, query: str, max_iterations: int = 100, 
                db_type: str = 'libsql'):
    durations = []
    results_count = 0
    conn = init_db(config, db_type)
    
    countries = get_all_countries(conn, db_type)
    iterations = min(len(countries), max_iterations)
    
    for country in countries[:iterations]:
        results, duration = execute_query(conn, query, (country,))
        durations.append(duration)
        results_count += len(results)
    
    # connection to libSQL db shall not be closed explicitly
    if db_type in ['sqlite', 'postgres', 'supabase']:
        conn.close()
    
    return {
        'db_type': db_type,
        'mean': statistics.mean(durations),
        'median': statistics.median(durations),
        'p95': statistics.quantiles(durations, n=20)[18],
        'min': min(durations),
        'max': max(durations),
        'std_dev': statistics.stdev(durations),
        'iterations': iterations,
        'avg_per_row': sum(durations) / results_count if results_count > 0 else 0
    }

def compare_databases():
    query = 'SELECT * FROM cities WHERE country = ?'
    max_iterations = 5
    
    libsql_stats = run_benchmark(LIBSQL_CONFIG, query, max_iterations, 'libsql')
    sqlite_stats = run_benchmark(SQLITE_CONFIG, query, max_iterations, 'sqlite')
    postgres_stats = run_benchmark(POSTGRES_CONFIG, query, max_iterations, 'postgres')
    supabase_stats = run_benchmark(SUPABASE_CONFIG, query, max_iterations, 'supabase')
    turso_remote_stats = run_benchmark(TURSO_REMOTE_CONFIG, query, max_iterations, 'turso-remote')
    turso_embedded_stats = run_benchmark(TURSO_EMBEDDED_CONFIG, query, max_iterations, 'turso-embedded')
    
    headers = ['Metric', 'LibSQL', 'SQLite', 'PostgreSQL', 'Supabase', 'Turso-remote', 'Turso-embedded']
    rows = []
    metrics = [
        'mean', 'min', 'max'
    ]
    
    for metric in metrics:
        if metric == 'iterations':
            rows.append([
                metric,
                str(int(libsql_stats[metric])),
                str(int(sqlite_stats[metric])),
                str(int(postgres_stats[metric])),
                str(int(supabase_stats[metric])),
                str(int(turso_remote_stats[metric])),
                str(int(turso_embedded_stats[metric]))
            ])
        elif metric == 'avg_per_row':
            rows.append([
                'µs per result row',
                f"{libsql_stats[metric]:.2f}µs",
                f"{sqlite_stats[metric]:.2f}µs",
                f"{postgres_stats[metric]:.2f}µs",
                f"{supabase_stats[metric]:.2f}µs",
                f"{turso_remote_stats[metric]:.2f}µs",
                f"{turso_embedded_stats[metric]:.2f}µs"
            ])
        else:
            rows.append([
                metric,
                f"{libsql_stats[metric]:.2f}µs",
                f"{sqlite_stats[metric]:.2f}µs",
                f"{postgres_stats[metric]:.2f}µs",
                f"{supabase_stats[metric]:.2f}µs",
                f"{turso_remote_stats[metric]:.2f}µs",
                f"{turso_embedded_stats[metric]:.2f}µs"
            ])

    print("\nBenchmark Results:")
    print(f"Query: {query}")
    print(tabulate(rows, headers, tablefmt="grid"))

if __name__ == "__main__":
    compare_databases()
# Out:
# Found 240 unique countries in libsql : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Cote d'Ivoire, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, North Macedonia, Northern Mariana Islands, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States Virgin Islands, United States of America, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
# Found 240 unique countries in sqlite : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Cote d'Ivoire, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, North Macedonia, Northern Mariana Islands, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States Virgin Islands, United States of America, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
# Found 240 unique countries in postgres : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Cote d'Ivoire, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, Northern Mariana Islands, North Macedonia, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States of America, United States Virgin Islands, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
# Found 240 unique countries in supabase : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Anguilla, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Cote d'Ivoire, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, Northern Mariana Islands, North Macedonia, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States of America, United States Virgin Islands, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
# Found 241 unique countries in turso-remote : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, Netherlands Antilles, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, North Macedonia, Northern Mariana Islands, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Turks and Caicos Islands, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States Virgin Islands, United States of America, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
# 2024-11-05T13:22:57.351966Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# Found 241 unique countries in turso-embedded : Afghanistan, Albania, Algeria, American Samoa, Andorra, Angola, Antarctica (the territory South of 60 deg S), Antigua and Barbuda, Argentina, Armenia, Aruba, Australia, Austria, Azerbaijan, Bahamas, Bahrain, Bangladesh, Barbados, Belarus, Belgium, Belize, Benin, Bermuda, Bhutan, Bolivia, Bosnia and Herzegovina, Botswana, Bouvet Island (Bouvetoya), Brazil, British Indian Ocean Territory (Chagos Archipelago), British Virgin Islands, Brunei Darussalam, Bulgaria, Burkina Faso, Burundi, Cambodia, Cameroon, Canada, Cape Verde, Cayman Islands, Central African Republic, Chad, Chile, China, Christmas Island, Cocos (Keeling) Islands, Colombia, Comoros, Congo, Cook Islands, Costa Rica, Croatia, Cuba, Cyprus, Czech Republic, Denmark, Djibouti, Dominica, Dominican Republic, Ecuador, Egypt, El Salvador, Equatorial Guinea, Eritrea, Estonia, Ethiopia, Falkland Islands (Malvinas), Faroe Islands, Fiji, Finland, France, French Guiana, French Polynesia, French Southern Territories, Gabon, Gambia, Georgia, Germany, Ghana, Gibraltar, Greece, Greenland, Grenada, Guadeloupe, Guam, Guatemala, Guernsey, Guinea, Guinea-Bissau, Guyana, Haiti, Heard Island and McDonald Islands, Holy See (Vatican City State), Honduras, Hong Kong, Hungary, Iceland, India, Indonesia, Iran, Iraq, Ireland, Isle of Man, Israel, Italy, Jamaica, Japan, Jersey, Jordan, Kazakhstan, Kenya, Kiribati, Korea, Kuwait, Kyrgyz Republic, Lao People's Democratic Republic, Latvia, Lebanon, Lesotho, Liberia, Libyan Arab Jamahiriya, Liechtenstein, Lithuania, Luxembourg, Macao, Madagascar, Malawi, Malaysia, Maldives, Mali, Malta, Marshall Islands, Martinique, Mauritania, Mauritius, Mayotte, Mexico, Micronesia, Moldova, Monaco, Mongolia, Montenegro, Montserrat, Morocco, Mozambique, Myanmar, Namibia, Nauru, Nepal, Netherlands, Netherlands Antilles, New Caledonia, New Zealand, Nicaragua, Niger, Nigeria, Niue, Norfolk Island, North Macedonia, Northern Mariana Islands, Norway, Oman, Pakistan, Palau, Palestinian Territory, Panama, Papua New Guinea, Paraguay, Peru, Philippines, Pitcairn Islands, Poland, Portugal, Puerto Rico, Qatar, Reunion, Romania, Russian Federation, Rwanda, Saint Barthelemy, Saint Helena, Saint Kitts and Nevis, Saint Lucia, Saint Martin, Saint Pierre and Miquelon, Saint Vincent and the Grenadines, Samoa, San Marino, Sao Tome and Principe, Saudi Arabia, Senegal, Serbia, Seychelles, Sierra Leone, Singapore, Slovakia (Slovak Republic), Slovenia, Solomon Islands, Somalia, South Africa, South Georgia and the South Sandwich Islands, Spain, Sri Lanka, Sudan, Suriname, Svalbard & Jan Mayen Islands, Swaziland, Sweden, Switzerland, Syrian Arab Republic, Taiwan, Tajikistan, Tanzania, Thailand, Timor-Leste, Togo, Tokelau, Tonga, Trinidad and Tobago, Tunisia, Turkey, Turkmenistan, Turks and Caicos Islands, Tuvalu, Uganda, Ukraine, United Arab Emirates, United Kingdom, United States Minor Outlying Islands, United States Virgin Islands, United States of America, Uruguay, Uzbekistan, Vanuatu, Venezuela, Vietnam, Wallis and Futuna, Western Sahara, Yemen, Zambia, Zimbabwe
#
# Benchmark Results:
# Query: SELECT * FROM cities WHERE country = ?
# +----------+----------+----------+--------------+------------+----------------+------------------+
# | Metric   | LibSQL   | SQLite   | PostgreSQL   | Supabase   | Turso-remote   | Turso-embedded   |
# +==========+==========+==========+==============+============+================+==================+
# | mean     | 54.40µs  | 23.80µs  | 1681.20µs    | 12825.40µs | 55729.40µs     | 58.00µs          |
# +----------+----------+----------+--------------+------------+----------------+------------------+
# | median   | 28.00µs  | 14.00µs  | 1280.00µs    | 12899.00µs | 46684.00µs     | 47.00µs          |
# +----------+----------+----------+--------------+------------+----------------+------------------+
# | min      | 21.00µs  | 13.00µs  | 341.00µs     | 12319.00µs | 41684.00µs     | 43.00µs          |
# +----------+----------+----------+--------------+------------+----------------+------------------+
# | max      | 152.00µs | 63.00µs  | 3672.00µs    | 13226.00µs | 96077.00µs     | 106.00µs         |
# +----------+----------+----------+--------------+------------+----------------+------------------+
# 2024-11-05T13:22:57.468308Z  WARN libsql::replication::remote_client: Frames prefetching failed because of new session token returned by handshake

# %% [markdown]
# ## Add fictious data to Turso, remote and embedded
#
# No idea why running Turso-specific code works better than running all dbs together, but I had no time to debug...
#
# The code below inserts in batches, whereas the code above uses pandas to do bulk-inserts.

# %%
from faker import Faker
import pandas as pd
import sqlite3 as sqlite
import libsql_experimental as libsql
import psycopg2
import os

from datetime import datetime
from sqlalchemy import create_engine, text

from dotenv import load_dotenv

load_dotenv()


# ====================== CONFIGURATIONS ======================

num_records = 1000
batch_size = 10
   
# ====================== DATABASE CONFIGURATIONS ======================


#TURSO_CONFIG = {
#    'url': os.getenv('TURSO_REMOTE_DATABASE_URL'),
#    'auth_token': os.getenv('TURSO_REMOTE_AUTH_TOKEN')
#}


TURSO_CONFIG = {
    'remote': {
        'url': os.getenv('TURSO_REMOTE_DATABASE_URL'),
        'auth_token': os.getenv('TURSO_REMOTE_AUTH_TOKEN')
    },
    'embedded': {
        'url': 'turso-embedded-cities.db',  # local database path
        'sync_url': os.getenv('TURSO_EMBEDDED_SYNC_URL'),       # remote sync URL
        'auth_token': os.getenv('TURSO_EMBEDDED_AUTH_TOKEN')
    }
}

# Debug print to check configurations
print("\nConfiguration details:")
print("Remote config:", TURSO_CONFIG['remote'])
print("Embedded config:", TURSO_CONFIG['embedded'])


# ====================== DATABASE WRITERS ======================



def write_to_turso(df: pd.DataFrame, config: dict, db_type: str) -> float:
    print(f"\nWriting to Turso {db_type}...")
    print("=" * 20)

    conn = None
    duration = 0
    
    try:
        print(f"Connecting to Turso {db_type}...")
        if db_type == 'remote':
            conn = libsql.connect(config['url'], auth_token=config['auth_token'])
        else:  # embedded
            conn = libsql.connect(
                config['url'],
                sync_url=config['sync_url'],
                auth_token=config['auth_token']
            )
            conn.sync()
        
        cursor = conn.cursor()

        # Drop existing table
        print("Dropping existing table in Turso...")
        cursor.execute("DROP TABLE IF EXISTS cities")
        conn.commit()

        # Create table
        print("Creating table in Turso...")
        cursor.execute("""
            CREATE TABLE IF NOT EXISTS cities (
                city TEXT,
                country TEXT,
                inhabitants INTEGER
            )
        """)
        conn.commit()

        # Create index
        print("Creating index in Turso...")
        try:
            cursor.execute("CREATE INDEX IF NOT EXISTS idx_cities_country ON cities(country)")
            conn.commit()
        except Exception as e:
            print(f"Note: Index creation failed (might already exist): {e}")

        # Start timer
        start_time = datetime.now()
        
        # Insert data in batches
        for i in range(0, len(df), batch_size):
            batch = df.iloc[i:i + batch_size]
            values = [tuple(x) for x in batch.values]
            
            for value in values:
                cursor.execute(
                    "INSERT INTO cities (city, country, inhabitants) VALUES (?, ?, ?)",
                    value
                )
        
        conn.commit()
        
        duration = (datetime.now() - start_time).total_seconds()

        # Test queries
        print("\nTesting: Querying largest city...")
        cursor.execute("""
           SELECT city, country, inhabitants 
           FROM cities 
           ORDER BY inhabitants DESC 
           LIMIT 1
        """)
        result = cursor.fetchone()
        print(f"Largest city: {result[0]}, {result[1]} with {result[2]:,} inhabitants")

        print("\nTesting: Querying number of cities...")
        cursor.execute("SELECT COUNT(*) as total_rows FROM cities;")
        result = cursor.fetchone()
        print(f"Number of cities: {result[0]} ")

    finally:
        if conn:
            if db_type == 'embedded':
                conn.sync()  # Final sync for embedded database
            

    return duration

def main():
    
    # Generate data
    print(f"Generating {num_records} fake records...")
    fake = Faker()
    cities_data = [(fake.city(), fake.country(), fake.random_number()) 
                   for _ in range(num_records)]
    df = pd.DataFrame(cities_data, columns=['city', 'country', 'inhabitants'])
    
    # Dictionary to store durations
    durations = {}
    
    # Write to all databases
   
    # durations['Turso-remote'] = write_to_turso(df, TURSO_CONFIG['url'], TURSO_CONFIG['auth_token'])
    
    durations['Turso-remote'] = write_to_turso(df, TURSO_CONFIG['remote'], 'remote')
    durations['Turso-embedded'] = write_to_turso(df, TURSO_CONFIG['embedded'], 'embedded')
    
    # Print summary
    print("\nSummary of write performance:")
    for db_name, duration in durations.items():
        print(f"{db_name}: {duration:.2f} seconds")
    print(f"\nRecords written to each database: {num_records}")


  
if __name__ == "__main__":
    main()
# Out:
# Configuration details:
# Remote config: {'url': 'libsql://cities-gernotstarke.turso.io', 'auth_token': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MzA3NDMyODQsImlkIjoiN2U0NDkyN2EtNjNiMy00NmQ0LTg3ZmQtNjM0NzMyNDcxNzcwIn0.6598ZrKA50XIihSE2daj2v46dJkXgl8vg2I95dMq3BkIOl79HmoB5WRazrr_jK3Cha2G8XwkjMkA1gaW6GhABA'}
# Embedded config: {'url': 'turso-embedded-cities.db', 'sync_url': 'libsql://embedded-cities-gernotstarke.turso.io', 'auth_token': 'eyJhbGciOiJFZERTQSIsInR5cCI6IkpXVCJ9.eyJpYXQiOjE3MzA3OTE5MDgsImlkIjoiNzNjMTA3MmUtZjY0ZC00NzYwLTg2MGItMDJjYzA0MTFhN2NjIn0.AfFdinVGcZxnjmWZ31fx6Rf7aSSG78g5wGMO6fTHycDqwkpteEHETpXv6RQsjMgR2Q_YG-f9ZjyXwgY4dpMdDg'}
# Generating 1000 fake records...
#
# Writing to Turso remote...
# ====================
# Connecting to Turso remote...
# Dropping existing table in Turso...
# Creating table in Turso...
# Creating index in Turso...
#
# Testing: Querying largest city...
# Largest city: Lake Christopherbury, Djibouti with 994,087,135 inhabitants
#
# Testing: Querying number of cities...
# Number of cities: 1000
#
# Writing to Turso embedded...
# ====================
# Connecting to Turso embedded...
# 2024-11-05T13:15:11.561642Z  WARN libsql::hrana::hyper: tried to send request to `https://cities-gernotstarke.turso.io/v3/pipeline` while no runtime was available
# 2024-11-05T13:15:11.743649Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# Dropping existing table in Turso...
# Creating table in Turso...
# 2024-11-05T13:15:11.832163Z  WARN libsql::replication::remote_client: Frames prefetching failed because of new session token returned by handshake
# 2024-11-05T13:15:11.958284Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.149586Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# Creating index in Turso...
# 2024-11-05T13:15:12.293506Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.382188Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.505723Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.642406Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.766207Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:12.895719Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.022384Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.160705Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.288277Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.416407Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.541997Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.668168Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.794677Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:13.927306Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.067902Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.198925Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.324423Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.470060Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.611218Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.737448Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:14.865228Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.002324Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.135525Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.272603Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.434114Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.559877Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.693135Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.852124Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:15.974926Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.103586Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.234972Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.360267Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.489542Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.617815Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.741196Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.865247Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:16.993875Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.120057Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.242685Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.371913Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.497008Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.623727Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.774236Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:17.907071Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.030282Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.155849Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.285364Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.415766Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.547312Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.678718Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.807216Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:18.934397Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.069896Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.199849Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.327296Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.455122Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.580034Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.707761Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.863452Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:19.990580Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.114158Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.242281Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.376717Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.507353Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.634350Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.759361Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:20.886130Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.014587Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.143359Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.269917Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.397450Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.522626Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.648358Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.776525Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:21.902950Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.034271Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.165226Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.289751Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.425258Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.550000Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.688832Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.811363Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:22.938917Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.063987Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.189059Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.314592Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.441511Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.567679Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.700172Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.826476Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:23.954495Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.080811Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.212663Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.338945Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.464181Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.587555Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.712055Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.845527Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:24.976597Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.110639Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.240368Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.364124Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.494282Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.623578Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.753638Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:25.877434Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.004847Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.142188Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.269186Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.396959Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.521440Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.644764Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.773281Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:26.901349Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.026180Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.151454Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.276298Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.401005Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.525826Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.652328Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.776410Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:27.906710Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.035350Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.162602Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.287602Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.420759Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.546375Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.682917Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.815755Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:28.944095Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.092638Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.225913Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.356944Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.485088Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.613024Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.739855Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:29.926550Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.053844Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.185835Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.312471Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.439218Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.564240Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.694611Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.817711Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:30.944134Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.070947Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.201933Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.327089Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.455832Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.582509Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.706707Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.834177Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:31.957709Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.079673Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.202438Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.328637Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.455421Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.578172Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.703688Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.830608Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:32.956052Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.084424Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.213424Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.336518Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.462106Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.594016Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.719088Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.844252Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:33.972395Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.103891Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.233552Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.366867Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.489556Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.621635Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.755343Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:34.927743Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.058704Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.186139Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.311157Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.436987Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.567952Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.696626Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.824600Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:35.948053Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.077178Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.214926Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.356015Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.502592Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.639382Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.764247Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:36.893689Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.021325Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.153082Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.280995Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.413646Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.547504Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.675995Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.806701Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:37.932186Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.061878Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.197488Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.322075Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.449276Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.575550Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.702910Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:38.827347Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.000509Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.135820Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.267606Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.393508Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.517324Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.643549Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.772969Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:39.898874Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.025137Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.148390Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.274445Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.491474Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.627613Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.754399Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:40.882211Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.006026Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.130579Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.257043Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.380910Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.504919Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.634607Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.759149Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:41.886072Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.010734Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.133301Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.265185Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.392336Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.520276Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.646174Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.775482Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:42.899096Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.024220Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.150222Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.277067Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.403945Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.576461Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.705847Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.831736Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:43.956043Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.080857Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.207343Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.338989Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.465396Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.591914Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.715815Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.846143Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:44.980235Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.114749Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.240076Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.365582Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.493106Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.623054Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.748420Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.870723Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:45.997245Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.119440Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.248064Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.384237Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.513396Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.642454Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.765206Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:46.890531Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.023637Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.148776Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.276876Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.401983Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.529193Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.660520Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.783093Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:47.907378Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.030741Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.156226Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.282563Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.407587Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.532610Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.658952Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.797470Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:48.921278Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.043278Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.180968Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.321676Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.447032Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.577539Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.704445Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:49.888002Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.032676Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.173164Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.297818Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.420330Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.548435Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.673280Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.799571Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:50.924363Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.048361Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.173330Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.303810Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.438084Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.566179Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.701632Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.827709Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:51.952259Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.075171Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.200912Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.327999Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.456608Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.580670Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.708884Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.836942Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:52.963198Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.090482Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.215847Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.348053Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.472769Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.605887Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.734208Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.862577Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:53.985117Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.114957Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.239095Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.372803Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.497056Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.622226Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.758641Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:54.883370Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.014201Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.144091Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.243401Z  WARN libsql::replication::remote_client: Unusually long handshake. Took 99 ms, average 43 ms
# 2024-11-05T13:15:55.243450Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 98 ms, average 43 ms
# 2024-11-05T13:15:55.331273Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.460755Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.587159Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.714389Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.840205Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:55.964769Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.090478Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.213053Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.340118Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.472791Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.604301Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.728387Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.855921Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:56.980609Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.108123Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.232989Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.377613Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.501643Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.630015Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.758875Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:57.896124Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.026210Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.149881Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.299353Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.425256Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.553862Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.689135Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.817332Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:58.942486Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.068091Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.205807Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.332433Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.500451Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.653087Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.779223Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:15:59.906419Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.084075Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.212551Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.334514Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.460436Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.625690Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.758960Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:00.891267Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.022123Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.155875Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.292292Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.436810Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.570805Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.706364Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.835146Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:01.963615Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.086213Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.211744Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.333749Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.457464Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.583289Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.708640Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.839868Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:02.964235Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:03.091081Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:03.216771Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:03.351390Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:16:03.485214Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# ...
# 2024-11-05T13:17:05.907624Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.030931Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.156525Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.285527Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.410386Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.542286Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.696605Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.825346Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:06.960955Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.086347Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.225542Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.351177Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.479983Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.602437Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.730743Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:07.834674Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 103 ms, average 43 ms
# 2024-11-05T13:17:07.919930Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.057278Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.180920Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.306900Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.433610Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.563444Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.698007Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.820009Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:08.947798Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.070651Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.199175Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.336567Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.458674Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.588446Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.711736Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:09.837258Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.001685Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.125485Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.249681Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.374813Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.509716Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.651715Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.777920Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:10.902728Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.029849Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.152496Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.279029Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.415708Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.538410Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.666741Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.789898Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:11.912926Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.074881Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.202454Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.330020Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.458716Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.596422Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.722662Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:12.872428Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.002935Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.130869Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.254496Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.380272Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.505369Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.631313Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.756321Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:13.885353Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.014971Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.143231Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.303292Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.435141Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.561407Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.686978Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.815881Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:14.946191Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.072433Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.199704Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.330347Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.458033Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.591512Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.719672Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.845048Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:15.978127Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.105400Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.235762Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.359929Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.496043Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.626079Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.751720Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:16.876929Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.003667Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.130748Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.258278Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.388632Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.515805Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.639466Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.763417Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:17.886374Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.013740Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.141472Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.269404Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.396079Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.521939Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.650827Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.779656Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:18.907145Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.030947Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.155348Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.281546Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.407213Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.532454Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.663109Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.798669Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:19.939111Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.068663Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.213224Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.344128Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.533056Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.658609Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.787759Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:20.912620Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.039390Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.161090Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.285159Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.413301Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.538918Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.663760Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.788636Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:21.912813Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.035863Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.162870Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.291762Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.420085Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.547151Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.674829Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.803299Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.886730Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
# 2024-11-05T13:17:22.975991Z  WARN libsql::replication::remote_client: Unusually long frames fetch. Took 89 ms, average 43 ms
#
# Testing: Querying largest city...
# Largest city: Lake Christopherbury, Djibouti with 994,087,135 inhabitants
#
# Testing: Querying number of cities...
# Number of cities: 1000
# 2024-11-05T13:17:22.981679Z  INFO libsql::replication::remote_client: Attempting to perform handshake with primary.
#
# Summary of write performance:
# Turso-remote: 43.17 seconds
# Turso-embedded: 130.64 seconds
#
# Records written to each database: 1000
